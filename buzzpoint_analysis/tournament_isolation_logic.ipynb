# %%
import sqlite3

# %%
conn = sqlite3.connect('full_db.db')

# %%
import pandas as pd
tourney_df = pd.read_sql('SELECT * FROM tournament', conn)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2 tourney_df = pd.read_sql('SELECT * FROM tournament', conn)
#
# File ~/.local/lib/python3.12/site-packages/pandas/__init__.py:46
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
#      50     Int16Dtype,
#      51     Int32Dtype,
#      52     Int64Dtype,
#      53     UInt8Dtype,
#      54     UInt16Dtype,
#      55     UInt32Dtype,
#      56     UInt64Dtype,
#      57     Float32Dtype,
#      58     Float64Dtype,
#      59     CategoricalDtype,
#      60     PeriodDtype,
#      61     IntervalDtype,
#      62     DatetimeTZDtype,
#      63     StringDtype,
# ...

# %%
list(tourney_df['name']).index('2025 ACF Nationals')
# Out:
# 97

# %%
my_tourney_id = list(tourney_df['name']).index('2025 ACF Nationals')

# %%
my_tourney = tourney_df.loc[my_tourney_id]

# %%
games_df = pd.read_sql('SELECT * FROM game', conn)

# %%
teams_df = pd.read_sql(f'SELECT * FROM team WHERE tournament_id = 98', conn)

# %%
games_df = pd.read_sql(f'SELECT * FROM game WHERE team_one_id IN {tuple(teams_df["id"])}', conn)

# %%
games_df
# Out:
#        id  round_id  tossups_read  team_one_id  team_two_id
# 0    6405      1092            20         1211         1212
# 1    6406      1092            20         1213         1214
# 2    6407      1092            20         1215         1216
# 3    6408      1092            20         1217         1218
# 4    6409      1092            20         1219         1220
# ..    ...       ...           ...          ...          ...
# 408  6813      1112            20         1216         1256
# 409  6814      1112            20         1234         1228
# 410  6815      1112            20         1251         1222
# 411  6816      1112            20         1253         1257
# 412  6817      1112            20         1255         1248
#
# [413 rows x 5 columns]

# %%
# TODO: Write this in line with all of the above 
def get_all_games(tourney_name):
    tourney_id = tourney['id']
    print(tourney_id)

get_all_games(my_tourney)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       3     tourney_id = tourney['id']
#       4     print(tourney_id)
# ----> 6 get_all_games(my_tourney)
#
# NameError: name 'my_tourney' is not defined
